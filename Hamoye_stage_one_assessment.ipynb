# %% [markdown]
# <a href="https://colab.research.google.com/github/babzchizzy/Hamoye-stage-one-assessment/blob/master/Hamoye_stage_one_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url= 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data= pd.read_csv(url, error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# count                    29523  ...         29523.000000
# unique                   29523  ...                  NaN
# top     f1_fuel_2002_12_79_0_2  ...                  NaN
# freq                         1  ...                  NaN
# mean                       NaN  ...            19.304354
# std                        NaN  ...          2091.540939
# min                        NaN  ...           -41.501000
# 25%                        NaN  ...             1.940000
# 50%                        NaN  ...             4.127000
# 75%                        NaN  ...             7.745000
# max                        NaN  ...        359278.000000
#
# [11 rows x 11 columns]

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data[['fuel_unit']]=fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  ...  fuel_cost_per_mmbtu
# fuel_type_code_pudl                          ...
# coal                  f1_fuel_1994_12_1_0_7  ...                1.121
# gas                  f1_fuel_1994_12_2_0_10  ...                2.570
# nuclear               f1_fuel_1994_12_2_1_1  ...                0.450
# oil                   f1_fuel_1994_12_6_0_2  ...                5.469
# other                f1_fuel_1994_12_11_0_6  ...                2.335
# waste                 f1_fuel_1994_12_9_0_3  ...                1.072
#
# [6 rows x 10 columns]

# %%
fuel_data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
fuel_df1= fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2= fuel_data.iloc[19000:].reset_index(drop=True)

# %%
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
pd.merge(fuel_df1, fuel_df2, how='inner')
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
pd.merge(fuel_df1, fuel_df2, how='outer')
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
pd.merge(fuel_df1, fuel_df2, how='left')
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# 0         f1_fuel_1994_12_1_0_7  ...                1.121
# 1        f1_fuel_1994_12_1_0_10  ...                1.120
# 2         f1_fuel_1994_12_2_0_1  ...                1.650
# 3         f1_fuel_1994_12_2_0_7  ...                1.970
# 4        f1_fuel_1994_12_2_0_10  ...                2.570
# ...                         ...  ...                  ...
# 18995   f1_fuel_2009_12_182_1_9  ...                4.711
# 18996  f1_fuel_2009_12_182_1_10  ...               14.634
# 18997  f1_fuel_2009_12_182_1_13  ...                1.107
# 18998  f1_fuel_2009_12_182_1_14  ...               15.102
# 18999    f1_fuel_2009_12_79_0_1  ...                1.727
#
# [19000 rows x 11 columns]

# %%
data_to_concat=pd.get_dummies(fuel_df2)

# %%
pd.concat([fuel_df1, data_to_concat]).reset_index(drop=True)
# Out:
#                     record_id  utility_id_ferc1  ...  fuel_unit_mwhth fuel_unit_ton
# 0       f1_fuel_1994_12_1_0_7                 1  ...              NaN           NaN
# 1      f1_fuel_1994_12_1_0_10                 1  ...              NaN           NaN
# 2       f1_fuel_1994_12_2_0_1                 2  ...              NaN           NaN
# 3       f1_fuel_1994_12_2_0_7                 2  ...              NaN           NaN
# 4      f1_fuel_1994_12_2_0_10                 2  ...              NaN           NaN
# ...                       ...               ...  ...              ...           ...
# 29518                     NaN                12  ...              0.0           0.0
# 29519                     NaN                12  ...              0.0           0.0
# 29520                     NaN                12  ...              0.0           0.0
# 29521                     NaN                12  ...              0.0           1.0
# ...

# %% [markdown]
# checking for duplicates

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit={'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
                        'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]}
pd.DataFrame(fuel_unit)                        
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('fuel_unit')
# Out:
# Text(0.5, 0, 'fuel_unit')

# %% [markdown]
# plotting a bar plot

# %%
g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale('log')
g.set_ylim(1, 12000)
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel>

# %% [markdown]
# plotting a scatter plot

# %%
sample_df=fuel_data.sample(n=50, random_state=4)
sns.regplot(x=sample_df['utility_id_ferc1'], y=sample_df['fuel_cost_per_mmbtu'], fit_reg=False)

# %% [markdown]
# box plot

# %%
sns.boxplot(x='fuel_type_code_pudl', y='utility_id_ferc1', palette=['m', 'g'], data=fuel_data)

# %% [markdown]
# violin plot

# %%
sns.violinplot(x='fuel_type_code_pudl', y='utility_id_ferc1', data=fuel_data)

# %% [markdown]
# KDE plot

# %%
sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color='g')

# %% [markdown]
# plotting a heatmap

# %%
correlation= fuel_data.corr()
sns.heatmap(correlation, annot=True, xticklabels=correlation.columns, yticklabels=correlation.columns)
